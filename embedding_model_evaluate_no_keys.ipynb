# %% [markdown]
# ### Load a model from a description using embeddings (with a datastore to optimize multiple searches)
# ##### by: Ben Gibbons (https://bgibbonsweb.github.io/)
#
# To run this notebook, you'll need both a SketchFab Api Token & an OpenAI key

# %%
freeze_model_database_models = True
maxModelFaces = 5 * 1000
minModelFaces = 1 * 1000
min_image_size = 350
ai_model = "gpt-4o-mini"
model_download_path = "./downloaded_models"

modelToDownload = "Silver car"
model_name = "ViT-H/14-378"
pretrained = "dfn5b"

# model_name = "ViT-B/32"
# pretrained = "dfn5b"

# %%
# !pip install numpy==1.26.4 requests==2.32.3 torch==2.5.1 pillow==10.3.0 open_clip_torch==2.30.0 openai pillow==10.3.0 torchvision==0.20.1

# %%
import gc
import json
import os
from io import BytesIO

import numpy as np
import requests
import torch
from PIL import Image

import clip
import open_clip
from openai import OpenAI
import zipfile
from getpass import getpass

open_ai_key = getpass("Enter your OpenAI API key: ")
sketchfab_api_token = getpass("Enter your Sketchfab API token: ")

# %%
available_models = open_clip.list_models()
for model in available_models:
    print(model)
# Out:
# coca_base
# coca_roberta-ViT-B-32
# coca_ViT-B-32
# coca_ViT-L-14
# convnext_base
# convnext_base_w
# convnext_base_w_320
# convnext_large
# convnext_large_d
# convnext_large_d_320
# convnext_small
# convnext_tiny
# convnext_xlarge
# convnext_xxlarge
# convnext_xxlarge_320
# EVA01-g-14
# EVA01-g-14-plus
# EVA02-B-16
# EVA02-E-14
# EVA02-E-14-plus
# EVA02-L-14
# EVA02-L-14-336
# MobileCLIP-B
# MobileCLIP-S1
# MobileCLIP-S2
# mt5-base-ViT-B-32
# mt5-xl-ViT-H-14
# nllb-clip-base
# nllb-clip-base-siglip
# nllb-clip-large
# nllb-clip-large-siglip
# RN50
# RN50-quickgelu
# RN50x4
# RN50x4-quickgelu
# RN50x16
# RN50x16-quickgelu
# RN50x64
# RN50x64-quickgelu
# RN101
# RN101-quickgelu
# roberta-ViT-B-32
# swin_base_patch4_window7_224
# ViT-B-16
# ViT-B-16-plus
# ViT-B-16-plus-240
# ViT-B-16-quickgelu
# ViT-B-16-SigLIP
# ViT-B-16-SigLIP-256
# ViT-B-16-SigLIP-384
# ViT-B-16-SigLIP-512
# ViT-B-16-SigLIP-i18n-256
# ViT-B-32
# ViT-B-32-256
# ViT-B-32-plus-256
# ViT-B-32-quickgelu
# ViT-bigG-14
# ViT-bigG-14-CLIPA
# ViT-bigG-14-CLIPA-336
# ViT-bigG-14-quickgelu
# ViT-e-14
# ViT-g-14
# ViT-H-14
# ViT-H-14-378
# ViT-H-14-378-quickgelu
# ViT-H-14-CLIPA
# ViT-H-14-CLIPA-336
# ViT-H-14-quickgelu
# ViT-H-16
# ViT-L-14
# ViT-L-14-280
# ViT-L-14-336
# ViT-L-14-336-quickgelu
# ViT-L-14-CLIPA
# ViT-L-14-CLIPA-336
# ViT-L-14-quickgelu
# ViT-L-16
# ViT-L-16-320
# ViT-L-16-SigLIP-256
# ViT-L-16-SigLIP-384
# ViT-M-16
# ViT-M-16-alt
# ViT-M-32
# ViT-M-32-alt
# ViT-S-16
# ViT-S-16-alt
# ViT-S-32
# ViT-S-32-alt
# ViT-SO400M-14-SigLIP
# ViT-SO400M-14-SigLIP-378
# ViT-SO400M-14-SigLIP-384
# ViT-SO400M-16-SigLIP-i18n-256
# vit_medium_patch16_gap_256
# vit_relpos_medium_patch16_cls_224
# ViTamin-B
# ViTamin-B-LTT
# ViTamin-L
# ViTamin-L2
# ViTamin-L2-256
# ViTamin-L2-336
# ViTamin-L2-384
# ViTamin-L-256
# ViTamin-L-336
# ViTamin-L-384
# ViTamin-S
# ViTamin-S-LTT
# ViTamin-XL-256
# ViTamin-XL-336
# ViTamin-XL-384
# xlm-roberta-base-ViT-B-32
# xlm-roberta-large-ViT-H-14

# %%
client = OpenAI(api_key=open_ai_key)
if not os.path.exists(model_download_path):
    os.mkdir(model_download_path)

# %%
def askMultiQuestion(questions, the_model = ai_model):
    print("askMultiQuestion", the_model, questions[0])
    messages = []
    messages.append({ "role": "system", "content": "You are a helpful assistant." })
    ai_resp = ""

    while len(questions) > 0:
        question = questions.pop(0)
        print("")
        print("<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<")
        print("")
        print(question)
        messages.append({"role": "user", "content": question})

        completion = client.chat.completions.create(
            model=the_model,
            messages=messages
        )

        ai_resp = completion.choices[0].message.content.strip()
        messages.append({"role": "assistant", "content": ai_resp})
        print("")
        print(">>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>")
        print("")
        print(ai_resp)

    return ai_resp, messages

# %% [markdown]
# ### Load past search data for speedup

# %%
# load the clip model
device = "cuda" if torch.cuda.is_available() else "cpu"

if model_name == "ViT-B/32":
    clip_model, clip_preprocess = clip.load("ViT-B/32", device=device)
else:
    clip_model, nuttin, clip_preprocess = open_clip.create_model_and_transforms(model_name, pretrained=pretrained)
    clip_model = clip_model.to(device)

# Attempt to load the database
num_model_loads = 0
existing_image_features = None
existing_text_features = None
list_of_all_models = { }
existing_searches_done = []
index_to_model_uid = []
num_models_downloaded = 0
stack_existing_image_features = True

model_name_for_file = model_name.replace("/", "_")
saved_model_data_filename = f'./saved_model_data_{model_name_for_file}.json'
existing_image_features_filename = f'./existing_image_features_{model_name_for_file}.pt'
existing_text_features_filename = f"./existing_text_features_{model_name_for_file}.pt"

try:
    with open(saved_model_data_filename, 'r') as json_file:
        saved_model_data = json.load(json_file)
        existing_searches_done = saved_model_data["existing_searches_done"]
        list_of_all_models = saved_model_data["list_of_all_models"]
        index_to_model_uid = saved_model_data["index_to_model_uid"]
        print("index_to_model_uid", len(index_to_model_uid))
    existing_image_features = torch.load(existing_image_features_filename)
    print("existing_image_features", existing_image_features.shape)
    existing_text_features = torch.load(existing_text_features_filename)
    print("existing_text_features", existing_text_features.shape)
    assert existing_image_features.shape == existing_text_features.shape
except Exception as e:
    print(e)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/open_clip/factory.py:380: UserWarning: These pretrained weights were trained with QuickGELU activation but the model config does not have that enabled. Consider using a model config with a "-quickgelu" suffix or enable with a flag.
#   warnings.warn(
# index_to_model_uid 1235
# existing_image_features torch.Size([1235, 1024])
# existing_text_features torch.Size([1235, 1024])
# /var/folders/y_/z74vbjzj55j3pwdjqvqc9llm0000gn/T/ipykernel_60972/55422351.py:32: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   existing_image_features = torch.load(existing_image_features_filename)
# /var/folders/y_/z74vbjzj55j3pwdjqvqc9llm0000gn/T/ipykernel_60972/55422351.py:34: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   existing_text_features = torch.load(existing_text_features_filename)

# %%
def addSearchableModel(uid, image_url, name):
    global existing_image_features
    global existing_text_features
    global num_model_loads

    if not uid in list_of_all_models:
        response = requests.get(image_url)
        if response.status_code == 200:
            image = Image.open(BytesIO(response.content))

            if image.width < min_image_size or image.height < min_image_size:
                return
            
            tokenized_text = open_clip.tokenize(name).to(device)

            with torch.no_grad():
                new_text_features = clip_model.encode_text(tokenized_text).detach()
                
            # Normalize the features (optional but recommended)
            new_text_features = new_text_features / new_text_features.norm(dim=-1, keepdim=True)
            new_text_features_np = new_text_features.to(device).detach()

            if existing_text_features is not None:
                existing_text_features = torch.cat([existing_text_features.to(device), new_text_features_np], dim=0)
            else:
                existing_text_features = new_text_features_np
            
            new_text_features_np.detach()
            del new_text_features
            del new_text_features_np

            # image checking       
            image_tensor = clip_preprocess(image).to(device).detach().unsqueeze(0)
            
            # image_batch = torch.cat(image_tensor).to(device)  # Combine images into a batch
            image_features = clip_model.encode_image(image_tensor).to(device).detach()
            image_features /= image_features.norm(dim=-1, keepdim=True)  # Normalize features
            new_image_features_np = image_features.to(device).detach()

            if existing_image_features is not None:
                existing_image_features = torch.cat([existing_image_features.to(device), new_image_features_np], dim=0)
            else:
                existing_image_features = new_image_features_np
            
            list_of_all_models[uid] = { "name": name, "image": image_url, "uid": uid }
            index_to_model_uid.append(uid)
            num_model_loads += 1
            
            del new_image_features_np
            del image
            del image_tensor
            del image_features

            # Trigger garbage collection and print uncollectable objects
            gc.collect()

            torch.cuda.empty_cache()  # Clear GPU memory
            print("addSearchableModel", name, uid, image_url)
            
            with open(saved_model_data_filename, "w") as f:
                saved_model_data = { "existing_searches_done": existing_searches_done, "list_of_all_models": list_of_all_models, "index_to_model_uid": index_to_model_uid }
                json.dump(saved_model_data, f)
            torch.save(existing_image_features.cpu().detach(), existing_image_features_filename)
            torch.save(existing_text_features.cpu().detach(), existing_text_features_filename)
        else:
            print(f"Failed to fetch {image_url}. Status code: {response.status_code}")

# %%
modelsDownloaded = { }

# respect users who don't want their models used in any any related things
def hasNoAITag(model):
    if model["tags"]:
        for tagIter in model["tags"]:
            if "noai" in tagIter["name"].lower():
                return True
    return False

def getModelList(objectName):

    try:
        # Specify the URL you want to request
        url = "https://api.sketchfab.com/v3/search?type=models&q=" + objectName + "&downloadable=true&min_face_count=" + str(minModelFaces) +  "&max_face_count=" + str(maxModelFaces) +  "&archives_flavours=false"
        print("url", url)

        # Send an HTTPS GET request
        response = requests.get(url)
        if response.status_code == 429:
            print("response.status_code == 429 sleeping for a minute")
            return ""    

        # Check if the request was successful (status code 200)
        if response.status_code == 200:
            data = json.loads(response.text)

            try:
                response = requests.get(url)
                if response.status_code == 200:
                    data = json.loads(response.text)
                    return_data = []
                    if data and data["results"] and data["results"][0]:
                        for iter in data["results"]:
                            if not hasNoAITag(iter):
                                return_data.append(iter)
                                addSearchableModel(iter["uid"], iter["thumbnails"]["images"][0]["url"], iter["name"])
                                
                        return return_data
                    
                else:
                    print(f"Failed to fetch {url}. Status code: {response.status_code}")
            except Exception as e:
                print("except Exception as e", e)
    except Exception as e:
        print("except Exception as e", e)

    return []

def download_one_model(model):
    global num_model_loads

    objectName = model["name"]
    modelUID = model["uid"]
    baseDir = model_download_path
    print("os.mkdir(baseDir): " + baseDir)

    if not os.path.exists("zipped_models"):
        os.mkdir("zipped_models")
    if not os.path.exists(baseDir):
        os.mkdir(baseDir)

    unzipped_file_path = baseDir + os.sep + modelUID
    
    if os.path.exists(unzipped_file_path):
        print("os.path.exists(unzipped_file_path): " + unzipped_file_path)
        modelsDownloaded[objectName] = modelUID
        return modelUID

    zipped_file_path = "zipped_models" + os.sep + modelUID + ".zip"

    if os.path.exists(zipped_file_path):
        with zipfile.ZipFile(zipped_file_path, 'r') as zip_ref:
            zip_ref.extractall(unzipped_file_path)
            print("os.path.exists(file_path): " + zipped_file_path)
        modelsDownloaded[objectName] = modelUID
        
        return modelUID

    url = "https://api.sketchfab.com/v3/models/" + model["uid"] + "/download"
    headers = {
        'Authorization': f"Token {sketchfab_api_token}"
    }
    params = {
        'mode': 'cors'
    }
    
    response = requests.get(url, headers=headers, params=params)
    modelData = json.loads(response.text)
            
    # Specify the URL of the file you want to download
    print("modelData", modelData, "response", response)

    if not "gltf" in modelData:
        return None

    file_url = modelData["gltf"]['url']
    print(file_url)

    # Send a GET request to the URL
    response = requests.get(file_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Get the content of the response and save it to a local file
        with open(zipped_file_path, "wb") as file:
            file.write(response.content)
            
            # Open the zip file
            with zipfile.ZipFile(zipped_file_path, 'r') as zip_ref:
                
                zip_ref.extractall(unzipped_file_path)
                print("Extracted", unzipped_file_path)
                modelsDownloaded[objectName] = modelUID
                
            num_model_loads += 1
            return modelUID
    else:
        print(f"Failed to download the file. Status code: {response.status_code}")
        
def zscore(similarity):
    return (similarity - similarity.mean()) / similarity.std()

def load_model_from_vec(objectName, num_top_models = 50):

    pos_prompts = [objectName, "cohesive attractive design", 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
    pos_weights=[1.1, 0.2, 0.2, 0.2, 0.4, 0.2]
 
    neg_prompts=[f"object in a room", "a complete room", 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale'] 
    neg_weights=[0.3, 0.3, 0.3, 0.3, 0.2, 0.1, 0.1]
    
    print("load_model_from_vec - Positive Prompts:", pos_prompts)
    print("load_model_from_vec - Negative Prompts:", neg_prompts)
    
    # ----- Compute positive embeddings -----
    pos_tokens = clip.tokenize(pos_prompts).to(device)
    with torch.no_grad():
        pos_embeddings = clip_model.encode_text(pos_tokens).to(device)
        pos_embeddings = pos_embeddings / pos_embeddings.norm(dim=-1, keepdim=True)
    
    # Weight and combine the positive embeddings.
    weighted_pos = torch.stack([w * emb for w, emb in zip(pos_weights, pos_embeddings)], dim=0)
    combined_pos = weighted_pos.sum(dim=0)
    
    # ----- Compute negative embeddings (if any) -----
    if neg_prompts:
        neg_tokens = clip.tokenize(neg_prompts).to(device)
        with torch.no_grad():
            neg_embeddings = clip_model.encode_text(neg_tokens).to(device)
            neg_embeddings = neg_embeddings / neg_embeddings.norm(dim=-1, keepdim=True)
        weighted_neg = torch.stack([w * emb for w, emb in zip(neg_weights, neg_embeddings)], dim=0)
        combined_neg = weighted_neg.sum(dim=0)
    else:
        # If no negative prompts are provided, use a zero tensor of the same shape.
        combined_neg = torch.zeros_like(combined_pos)
    
    # ----- Combine positive and negative embeddings -----
    combined_text = combined_pos - combined_neg
    combined_text = combined_text / combined_text.norm()
    
    # ----- Compute similarity with existing image features -----
    # (Assuming existing_image_features is a [N x D] tensor where D is the embedding dim.)
    combined_similarity = (existing_image_features @ combined_text.T).squeeze()
    combined_similarity = zscore(combined_similarity.cpu().numpy())

    top_X_indices = np.argsort(-combined_similarity)[:num_top_models]
    top_X_models = [list_of_all_models[index_to_model_uid[idx]] for idx in top_X_indices]
    
    gc.collect()  # Run garbage collection
    torch.cuda.empty_cache()  # Clear GPU memory

    return top_X_models


def downloadModel(objectName, num_top_models = 5):
    
    room_plus_object = objectName

    if objectName in modelsDownloaded:
        print("return modelsDownloaded[objectName]", objectName)
        download_one_model({ "uid": modelsDownloaded[objectName], 'name': objectName})
        return modelsDownloaded[objectName]

    if objectName in existing_searches_done or freeze_model_database_models:
        return load_model_from_vec(room_plus_object, num_top_models)
    existing_searches_done.append(objectName)

    getModelList(objectName)
    modelTokens = objectName.split(' ')
    if len(modelTokens) > 5:
        subDesc = askMultiQuestion([f"If I was searching in a model database for \"{objectName}\" and could only search using five words, which words should I use? Avoid using plural words.", "Say the words.  Just say five words.  Don't say anything else.  Just five.  That's it."])[0].strip().replace("\"", "").replace("\'","")
        if subDesc not in existing_searches_done:
            existing_searches_done.append(subDesc)
            getModelList(subDesc)

    if len(modelTokens) > 4:
        subDesc = askMultiQuestion([f"If I was searching in a model database for \"{objectName}\" and could only search using four words, which words should I use? Avoid using plural words.", "Say the words.  Just say four words.  Don't say anything else.  Just four.  That's it."])[0].strip().replace("\"", "").replace("\'","")
        if subDesc not in existing_searches_done:
            existing_searches_done.append(subDesc)
            getModelList(subDesc)

    if len(modelTokens) > 3:
        subDesc = askMultiQuestion([f"If I was searching in a model database for \"{objectName}\" and could only search using three words, which words should I use? Avoid using plural words.", "Say the words.  Just say three words.  Don't say anything else.  Just three.  That's it."])[0].strip().replace("\"", "").replace("\'","")
        if subDesc not in existing_searches_done:
            existing_searches_done.append(subDesc)
            getModelList(subDesc)

    if len(modelTokens) > 2:
        subDesc = askMultiQuestion([f"If I was searching in a model database for \"{objectName}\" and could only search using two words, which words should I use? Avoid using plural words.", "Say the words.  Just say two words.  Don't say anything else.  Just two.  That's it."])[0].strip().replace("\"", "").replace("\'","")
        if subDesc not in existing_searches_done:
            existing_searches_done.append(subDesc)
            getModelList(subDesc)
    
    for subDesc in modelTokens:
        if subDesc not in existing_searches_done:
            existing_searches_done.append(subDesc)
            getModelList(subDesc)

    return load_model_from_vec(room_plus_object, num_top_models)

# %%
model_uids = downloadModel(modelToDownload)
# Out:
# load_model_from_vec - Positive Prompts: ['Silver car', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# /var/folders/y_/z74vbjzj55j3pwdjqvqc9llm0000gn/T/ipykernel_60972/1822695210.py:163: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/TensorShape.cpp:3687.)
#   combined_similarity = (existing_image_features @ combined_text.T).squeeze()

# %%
print(modelToDownload)
for model in model_uids:
    print(model)
# Out:
# Silver car
# {'name': 'Mercedes-Benz Silver Lightning', 'image': 'https://media.sketchfab.com/models/cfba13ac9ad6440db68d6a65c22a01ed/thumbnails/47f98454fcd94794b680de12082b4724/d858ecb090c44f14bb48eb659f9dda52.jpeg', 'uid': 'cfba13ac9ad6440db68d6a65c22a01ed'}
# {'name': '2001 Mercedes-Benz A160 Hatchback', 'image': 'https://media.sketchfab.com/models/2cff998e65d44480af9d021a003ef000/thumbnails/c379468970af45ae87d7e12202018f52/ce8c462711e24101afec9650db66e723.jpeg', 'uid': '2cff998e65d44480af9d021a003ef000'}
# {'name': 'Sport Car', 'image': 'https://media.sketchfab.com/models/5bf9eb1870594f91a937e8cc2eb922f9/thumbnails/1ddfe8bef1ab4618b31ed864c613bf8a/219a3e6332ca43d6b85dd6a45e02a572.jpeg', 'uid': '5bf9eb1870594f91a937e8cc2eb922f9'}
# {'name': 'Kazē Strike fighter (The Koryu Unity)', 'image': 'https://media.sketchfab.com/models/50d5f90d49b44f7589d19b620a625c78/thumbnails/03d46510208f4a5c959d06193a965c33/19d19a379a044ca48a7dc92f8f8886e6.jpeg', 'uid': '50d5f90d49b44f7589d19b620a625c78'}
# {'name': 'Jeep Renegade 2016', 'image': 'https://media.sketchfab.com/models/192f7e81dce84c6780434f692a0f96c5/thumbnails/d33ed87b3f70409f937314ae905d044d/41fa0e482b694975b21226d46f1d40e0.jpeg', 'uid': '192f7e81dce84c6780434f692a0f96c5'}

# %%
ideal_dataset = [
    { "search": "Wall Lamp in a cozy bedroom", "uid": "ac14ea025c754e45a78306903f595a0c" },
    { "search": "chandelier in a fancy grand ballroom", "uid": "94a3c2f9d503434b87120f05e937db62" },
    { "search": "Dragon's Tooth with glowing red streaks", "uid": "f5fc6e1cd95f44de8319ddb1a2bedb26" },
    { "search": "Tree growing out of an acid swamp", "uid": "feb56a05db3546d390d0957e03cf48a3" },
    { "search": "Glittering Blue Geode", "uid": "22ff9332332542489dae0076180f7102" },
    { "search": "Tree in a cartoon or anime style", "uid": "0a91ecb8cd954fc19cca1a367f91555d" },
    { "search": "A robot dog carrying a bone in it's mouth", "uid": "22815eb3a5724962bb72db0b0570c097" },
    { "search": "A large troll carrying a club made of bones", "uid": "c8d0996144a848b8975727257427473f" },
    { "search": "An alien carrying a ray gun", "uid": "4979ba26b80d407f80cafc9fc5997f37" },
    { "search": "Large Ice sculpture of a figure skater", "uid": "9c69ffc8a44a431f9cfdf0eb78d82b8f" },
    { "search": "Christmas tree with a shining star at the top", "uid": "2683bbd6f802480cb36c901d357ff119" },
    { "search": "A dumptruck with yellow paint", "uid": "4dd5b3f4a84d473f9c73f2a1d43667ea" },
    { "search": "small cottage surrounded by grass", "uid": "816a9104b90d4a449f5162f7c144a54a" },
    { "search": "Silver car", "uid": "5bf9eb1870594f91a937e8cc2eb922f9" },
]
print(len(ideal_dataset))
# Out:
# 14

# %%
# freeze_model_database_models = True
drift_score = 0
max_score_per_item = 10
for item in ideal_dataset:
    tests_uids = downloadModel(item["search"], max_score_per_item)
    print(tests_uids)
    for model in tests_uids:
        if model['uid'] == item['uid']:
            break
        drift_score += 1
    print("drift_score", drift_score)

print("drift_score", drift_score)
# Out:
# load_model_from_vec - Positive Prompts: ['Wall Lamp in a cozy bedroom', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Retro/Vintage Wall Lamp', 'image': 'https://media.sketchfab.com/models/ac14ea025c754e45a78306903f595a0c/thumbnails/7892261363a74dbeafd521de47e38b3b/0879165e78844e84a32dcf43da4da53d.jpeg', 'uid': 'ac14ea025c754e45a78306903f595a0c'}, {'name': 'CC0 - Wall Lamp', 'image': 'https://media.sketchfab.com/models/e619e1b84af14194ac739712de4330b2/thumbnails/73091eb7f58145c99bd001a8b5490e88/f8b1d5ee6c8f40548dc709994e8ebf5f.jpeg', 'uid': 'e619e1b84af14194ac739712de4330b2'}, {'name': 'Unseen: Wall Lamp', 'image': 'https://media.sketchfab.com/models/dda408533ef54915b69d90f230b5e929/thumbnails/fe3515c22344480382fcd0e2642ec01b/a1fe0a64bd1f4ab5a3e258cc32641d0e.jpeg', 'uid': 'dda408533ef54915b69d90f230b5e929'}, {'name': 'Modern led wall lamp', 'image': 'https://media.sketchfab.com/models/e05f691e1262465b8780e0f336550c17/thumbnails/e017e985ce6941188c002ebe35c7c502/b333adde249b4be590366fa9070fbdd0.jpeg', 'uid': 'e05f691e1262465b8780e0f336550c17'}, {'name': 'Argon 4704 wall lamp', 'image': 'https://media.sketchfab.com/models/98b6b89273e3428087556f8a054c565b/thumbnails/d4762cbda1ab47cbaa7085f3dc298164/e1b70e2cb3a747efba0960f74849fef0.jpeg', 'uid': '98b6b89273e3428087556f8a054c565b'}, {'name': 'Wall Light', 'image': 'https://media.sketchfab.com/models/c723fa0a1ac3478790192acdb39161b0/thumbnails/9ea5f817837c4da4823a611a4d402ed4/c1196158ca2b4bf596fb3e5081eebb08.jpeg', 'uid': 'c723fa0a1ac3478790192acdb39161b0'}, {'name': 'Victorian Wall Lamp', 'image': 'https://media.sketchfab.com/models/027b8a1418c14f6495d284934e85e483/thumbnails/e06f516333dc4c638163679482bf4813/b53ef268cf8e45f4aedc149bb4a93359.jpeg', 'uid': '027b8a1418c14f6495d284934e85e483'}, {'name': 'wall lamp', 'image': 'https://media.sketchfab.com/models/e1d7c30cf46f4ac69f4b868f0b1b5561/thumbnails/6b45378def424e11b4143df531cabd35/f721e79e51cb4b8aaed6351f97d2203b.jpeg', 'uid': 'e1d7c30cf46f4ac69f4b868f0b1b5561'}, {'name': 'Wall lamp', 'image': 'https://media.sketchfab.com/models/e053f18243224866b3768f0257510b56/thumbnails/e614e77e7cab40b4a71a11780f081504/e71374c4d1dd4cfab2e90e6a7972339f.jpeg', 'uid': 'e053f18243224866b3768f0257510b56'}, {'name': 'Street Wall Lamp', 'image': 'https://media.sketchfab.com/models/feba064834de4bb3b8d99aa19cefe9c9/thumbnails/a598572fa2194f2ea4ca57a145dae029/990b02593b8a4dad9988faa3634b83a2.jpeg', 'uid': 'feba064834de4bb3b8d99aa19cefe9c9'}]
# drift_score 0
# load_model_from_vec - Positive Prompts: ['chandelier in a fancy grand ballroom', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Extravangard Chandelier', 'image': 'https://media.sketchfab.com/models/94a3c2f9d503434b87120f05e937db62/thumbnails/e24c09352dbe44b6944e425f434033ec/5f07c0034c974bce8e0084e47d61dc25.jpeg', 'uid': '94a3c2f9d503434b87120f05e937db62'}, {'name': 'Chandelier from Poly by Google', 'image': 'https://media.sketchfab.com/models/202cbb2a22ea4dda80160ec89a77dc39/thumbnails/f328b7c51ae040f58a73d625342d4a8f/7b54c43b0aa347d88840674e2d150139.jpeg', 'uid': '202cbb2a22ea4dda80160ec89a77dc39'}, {'name': 'Chandelier', 'image': 'https://media.sketchfab.com/models/ba90f173220944eea071e7839547ee4e/thumbnails/d6ea3cf870d8424a976adc053dc9d87b/9d91267551bb487b8a3273400e533fdd.jpeg', 'uid': 'ba90f173220944eea071e7839547ee4e'}, {'name': 'MassFX Practice - Fancy Tube', 'image': 'https://media.sketchfab.com/models/eedeab5fd54e41f793151d788ca28fa9/thumbnails/db271c39294b4bb89293bb51ba245fa0/78a16d405d5e4f9282b9657e5def028a.jpeg', 'uid': 'eedeab5fd54e41f793151d788ca28fa9'}, {'name': 'Chandelier Stylized [Game Ready]', 'image': 'https://media.sketchfab.com/models/316c303050894320bed37870e464a6f8/thumbnails/8c70483ae9fc4f979fb4570502e3c4db/fee6631d06e449d086f5e153abe79deb.jpeg', 'uid': '316c303050894320bed37870e464a6f8'}, {'name': 'Asset5 - Chandelier', 'image': 'https://media.sketchfab.com/models/53f91d53429e4c9c92c88bda5bb332e4/thumbnails/c589a98b4a8048ec9f7e49a025976d61/283e526f9c27463ebbd01a610e0f914e.jpeg', 'uid': '53f91d53429e4c9c92c88bda5bb332e4'}, {'name': 'Chandelier', 'image': 'https://media.sketchfab.com/models/b5e20b732d9449d0852e76272efcea0a/thumbnails/59f7a218952940fa818d60fd96bb0992/e468bb0a44ab4f20b6814f556a4c9ea6.jpeg', 'uid': 'b5e20b732d9449d0852e76272efcea0a'}, {'name': 'Chandelier', 'image': 'https://media.sketchfab.com/models/a8fc60fc85bd4b219fa4e5277683888f/thumbnails/8dde8ba101624cb2af373de0b14d8568/9b2733b5f391428a81d67132440ed5c8.jpeg', 'uid': 'a8fc60fc85bd4b219fa4e5277683888f'}, {'name': 'Clean Plate', 'image': 'https://media.sketchfab.com/models/aff1e1d9d9fb4abb89739fcf07b3009d/thumbnails/20c3b453834d4b20b1a4045645307895/1efd66467fd746f6b9b729ba91ab84bf.jpeg', 'uid': 'aff1e1d9d9fb4abb89739fcf07b3009d'}, {'name': 'Chandelier', 'image': 'https://media.sketchfab.com/models/59171352681843e6a9ebdb057347b8fd/thumbnails/358e18fe0d3a48e990b0d823a91d15ec/1920x1080.jpeg', 'uid': '59171352681843e6a9ebdb057347b8fd'}]
# drift_score 0
# load_model_from_vec - Positive Prompts: ["Dragon's Tooth with glowing red streaks", 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'a painting of a tree with flowers growing out', 'image': 'https://media.sketchfab.com/models/d77b7d7662f9439ca8547c32db97a70f/thumbnails/e8dfad299d094dce99b36bd5e66e9ad5/ef541ff450d94f1783d54f5407bfb438.jpeg', 'uid': 'd77b7d7662f9439ca8547c32db97a70f'}, {'name': 'Large Rock', 'image': 'https://media.sketchfab.com/models/d737038f81804c6393a625803c2bea18/thumbnails/836d3ec95d5046dfac410808304fa675/73532f212cc64a54923d16ce3e241b77.jpeg', 'uid': 'd737038f81804c6393a625803c2bea18'}, {'name': 'Red Glowing Sword', 'image': 'https://media.sketchfab.com/models/b28a8c6de1974cb0bcb45a43aa35b2b4/thumbnails/8aea965a69724401bdec46e2267ab30e/4b78e3083ab34b00a35ef42d36ee3b87.jpeg', 'uid': 'b28a8c6de1974cb0bcb45a43aa35b2b4'}, {'name': 'Orca Tooth', 'image': 'https://media.sketchfab.com/models/ec2569dbeb984fdda0837936afb4e37c/thumbnails/e7bfb635c2f74671a8dbe44ee4973aa4/f14188939ed84370be748ae192eec3b0.jpeg', 'uid': 'ec2569dbeb984fdda0837936afb4e37c'}, {'name': 'Hand-Painted Fantasy Rock', 'image': 'https://media.sketchfab.com/models/44ddebea740340d28d3b2f9dbb98820c/thumbnails/8a4ec8d23c754d22ab6bac785d284170/ffc3eb5ff0f54d3380bc6cc9f920ff3d.jpeg', 'uid': '44ddebea740340d28d3b2f9dbb98820c'}, {'name': 'Red Crystal', 'image': 'https://media.sketchfab.com/models/787e0860de81498bbffdcbf45ac39e24/thumbnails/612a52c2d4064a57b134d6717317e3b3/583d2ce95e7e4ddfb51cfa0f98e15c70.jpeg', 'uid': '787e0860de81498bbffdcbf45ac39e24'}, {'name': 'Glowing Rock', 'image': 'https://media.sketchfab.com/models/c1826814fe1641248fce16b79ac29e41/thumbnails/b1a86917bfed40a481407de3cdf9acbd/f3771502fe414edebad7d98b11cfb398.jpeg', 'uid': 'c1826814fe1641248fce16b79ac29e41'}, {'name': 'Of Planes and Satellites', 'image': 'https://media.sketchfab.com/models/db8f1c8cba3b464993e216acbf4a69b9/thumbnails/4053b6c643f849a8a18f04864ff600e8/9c6139c38f774bd6896bca96a0d659e7.jpeg', 'uid': 'db8f1c8cba3b464993e216acbf4a69b9'}, {'name': 'a colorful swirl is surrounded by bubbles on', 'image': 'https://media.sketchfab.com/models/4c7ba71e90e9456095573cbb7cb147c9/thumbnails/6c2b574292af455bad6643c6283c7eea/64ad2b2b1521438e97dfcf052e35fff2.jpeg', 'uid': '4c7ba71e90e9456095573cbb7cb147c9'}, {'name': 'Tooth', 'image': 'https://media.sketchfab.com/models/dc59368f1b4343deacdd2421ba4fc6ef/thumbnails/8c71ef87825d4ca69330e1892c952672/eaf08b23e3594f16a6dbda3ade86222a.jpeg', 'uid': 'dc59368f1b4343deacdd2421ba4fc6ef'}]
# drift_score 10
# load_model_from_vec - Positive Prompts: ['Tree growing out of an acid swamp', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Stylized low Poly Tropical Tree', 'image': 'https://media.sketchfab.com/models/f71321859b7c4805a934a08abee6fc8a/thumbnails/60d5dade11d3484b94ada3e3a53534c8/d0985cf39ac94464bcf14ca8fa68d73f.jpeg', 'uid': 'f71321859b7c4805a934a08abee6fc8a'}, {'name': 'a drawing of a skull surrounded by vines and', 'image': 'https://media.sketchfab.com/models/b2a6850d593f49c0b9d9999491f6892e/thumbnails/1c435ae266cd45f493038ec1044c38ef/9e08ee66bb2f4d24bf88c7ae8461b120.jpeg', 'uid': 'b2a6850d593f49c0b9d9999491f6892e'}, {'name': 'Bald Cypress', 'image': 'https://media.sketchfab.com/models/feb56a05db3546d390d0957e03cf48a3/thumbnails/854e2903bb1b4752bd6d3dc37a0e165a/a17d5bbf1eb14358b389031fd4c6dc70.jpeg', 'uid': 'feb56a05db3546d390d0957e03cf48a3'}, {'name': 'Ground floor with acid puddles', 'image': 'https://media.sketchfab.com/models/5e2953deef6e458d9e0d1f38a98da107/thumbnails/89d0ee5190a84f27b60548ee7462e99f/01dfcb6797df42c39aca0531b03f8cc6.jpeg', 'uid': '5e2953deef6e458d9e0d1f38a98da107'}, {'name': 'mangrove tree roots', 'image': 'https://media.sketchfab.com/models/c32d977c14e04e5ebc1fbef9b6111957/thumbnails/69167c57cb5e46a8b8402ea8b797542b/1c6861643b07495e949afd41086983f0.jpeg', 'uid': 'c32d977c14e04e5ebc1fbef9b6111957'}, {'name': 'Stylized Tree', 'image': 'https://media.sketchfab.com/models/113e4e48d4214b958d017157aeb6c8dd/thumbnails/4bec2a91f71547fdaf4cc527805c4bed/3e9b83ee16b0441fb0aee5c3133b4b9d.jpeg', 'uid': '113e4e48d4214b958d017157aeb6c8dd'}, {'name': '[Stylized] Tree stump', 'image': 'https://media.sketchfab.com/models/00c944f33e1046fdb16506ece49a3914/thumbnails/4a69e7caa9cc4326a08c7a9237e8ac19/282c57272e444f6aa9123ebfd2b0d9a2.jpeg', 'uid': '00c944f33e1046fdb16506ece49a3914'}, {'name': 'a colorful sculpture with bubbles coming out', 'image': 'https://media.sketchfab.com/models/ca35953a02f2448d809527162ed9e8f3/thumbnails/e11744f033d14618aa53cefd93eb1d46/1a331c9533da45358e33a62ed22eb02b.jpeg', 'uid': 'ca35953a02f2448d809527162ed9e8f3'}, {'name': 'a cartoon illustration of a mushroom growing', 'image': 'https://media.sketchfab.com/models/e89df5bac852443ba9aa10de79a42fbb/thumbnails/490466c15f334d3a9978505bcb753ba9/0b7cd01755034dc5a1b60e519cfc8cba.jpeg', 'uid': 'e89df5bac852443ba9aa10de79a42fbb'}, {'name': 'Handpainted Tree Stump - Practice', 'image': 'https://media.sketchfab.com/models/30da2e3e7d8c4a18a8efd6558c7fe034/thumbnails/fbadfc5bd74a4628826c143db37d348a/804e2394a4204e5e888a7ec1a7e0cf5f.jpeg', 'uid': '30da2e3e7d8c4a18a8efd6558c7fe034'}]
# drift_score 12
# load_model_from_vec - Positive Prompts: ['Glittering Blue Geode', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Small Geode', 'image': 'https://media.sketchfab.com/models/22ff9332332542489dae0076180f7102/thumbnails/877a8cc8a98e4195aedbcae3379e13de/07dac95241e4434cb857757bb9a28171.jpeg', 'uid': '22ff9332332542489dae0076180f7102'}, {'name': 'Geode (Game Ready / 2K PBR)', 'image': 'https://media.sketchfab.com/models/2586fc1919514e33839c8beee16b93c2/thumbnails/9dae89a80364495eb4bd08107b9b8268/dad4ae1bb8244c80be02e0ee4e4b441b.jpeg', 'uid': '2586fc1919514e33839c8beee16b93c2'}, {'name': 'Large Geode', 'image': 'https://media.sketchfab.com/models/e6e259d5f1594c6fba3f3557722b7945/thumbnails/d36a899d7d6d4cccad7c0a991d9f6eb5/19febe412325420687c59eca316cd72f.jpeg', 'uid': 'e6e259d5f1594c6fba3f3557722b7945'}, {'name': 'Magical orb', 'image': 'https://media.sketchfab.com/models/5e2e0ac919cb4d30ac022133086c088c/thumbnails/7062dcb3d74f419dacef18592b0399dc/947eeb6a63fb4527909fcfa3088b55f7.jpeg', 'uid': '5e2e0ac919cb4d30ac022133086c088c'}, {'name': 'Large Rock', 'image': 'https://media.sketchfab.com/models/d737038f81804c6393a625803c2bea18/thumbnails/836d3ec95d5046dfac410808304fa675/73532f212cc64a54923d16ce3e241b77.jpeg', 'uid': 'd737038f81804c6393a625803c2bea18'}, {'name': 'Ice Cluster2 (free)', 'image': 'https://media.sketchfab.com/models/eb83bbed188e47bf9910b08e41e2956b/thumbnails/bf4ce6f10fd14565ac2067be07ba4088/12a2a516d05e49b0997ef3628032b2b3.jpeg', 'uid': 'eb83bbed188e47bf9910b08e41e2956b'}, {'name': 'The Dragons Egg: Geode', 'image': 'https://media.sketchfab.com/models/6b71aa4382264f958f8d4bbb6761580d/thumbnails/7e8bb97d67a549bdac223d62657eaad8/f8af6509933a474a805a509ee8c00189.jpeg', 'uid': '6b71aa4382264f958f8d4bbb6761580d'}, {'name': 'Glowing Gemstone', 'image': 'https://media.sketchfab.com/models/2adf9ed55f384d168bf9bf0e1fdd9589/thumbnails/d1bcf905f201463f8bd65a8688bcadfe/5803034f9c4c4902a52714c529a0a217.jpeg', 'uid': '2adf9ed55f384d168bf9bf0e1fdd9589'}, {'name': 'a colorful swirl is surrounded by bubbles on', 'image': 'https://media.sketchfab.com/models/4c7ba71e90e9456095573cbb7cb147c9/thumbnails/6c2b574292af455bad6643c6283c7eea/64ad2b2b1521438e97dfcf052e35fff2.jpeg', 'uid': '4c7ba71e90e9456095573cbb7cb147c9'}, {'name': 'Glowing Rock', 'image': 'https://media.sketchfab.com/models/c1826814fe1641248fce16b79ac29e41/thumbnails/b1a86917bfed40a481407de3cdf9acbd/f3771502fe414edebad7d98b11cfb398.jpeg', 'uid': 'c1826814fe1641248fce16b79ac29e41'}]
# drift_score 12
# load_model_from_vec - Positive Prompts: ['Tree in a cartoon or anime style', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Cartoon tree', 'image': 'https://media.sketchfab.com/models/0a91ecb8cd954fc19cca1a367f91555d/thumbnails/1c800947d7134bd29f633af3550ed3ba/a320f719d6dc4d39b5beb2be4f72033e.jpeg', 'uid': '0a91ecb8cd954fc19cca1a367f91555d'}, {'name': 'Tree Stair', 'image': 'https://media.sketchfab.com/models/23dd4bb4189f4fff9cc73ee4d280cc26/thumbnails/5ac12e6035d54c81a8c73d073e389633/b26790bf1e1a4237bda8a62227d958d5.jpeg', 'uid': '23dd4bb4189f4fff9cc73ee4d280cc26'}, {'name': 'Stylized Tree', 'image': 'https://media.sketchfab.com/models/c4e1c975a74c4ac4bc54da479b61a788/thumbnails/66cd438eeefe48ada550f27e49a453ba/6ccd1c2512734c19980451ffc4cca167.jpeg', 'uid': 'c4e1c975a74c4ac4bc54da479b61a788'}, {'name': 'Stylized low Poly Tropical Tree', 'image': 'https://media.sketchfab.com/models/f71321859b7c4805a934a08abee6fc8a/thumbnails/60d5dade11d3484b94ada3e3a53534c8/d0985cf39ac94464bcf14ca8fa68d73f.jpeg', 'uid': 'f71321859b7c4805a934a08abee6fc8a'}, {'name': 'Tree for Game', 'image': 'https://media.sketchfab.com/models/47e9e9f597d84d7b868e60baac4b879b/thumbnails/f17e2d8ea9a349d8a1fecbc2056f686e/6e1b62648ff342b9ab6e93946e206da1.jpeg', 'uid': '47e9e9f597d84d7b868e60baac4b879b'}, {'name': 'Jabami Anime Tree v3', 'image': 'https://media.sketchfab.com/models/02e0690cb6104098b47bfbbde5c6dd8a/thumbnails/bb577155b27a43ca8156925a518fb705/35e648051e2a46cb8805d0c864ff9369.jpeg', 'uid': '02e0690cb6104098b47bfbbde5c6dd8a'}, {'name': 'Stylized Tree', 'image': 'https://media.sketchfab.com/models/843278c62cb9494bafda67e7c14c5707/thumbnails/6d155621328c457082fb1f4500ea2bd1/2d63c2a215f549d292a5b29fb5aead9c.jpeg', 'uid': '843278c62cb9494bafda67e7c14c5707'}, {'name': 'Tree for game', 'image': 'https://media.sketchfab.com/models/6ee87b92564d4259b5a14e9a0dc68920/thumbnails/58b4a40c50f5461288067d4d0e3b0e0a/f7bfd9b162604153821a39c8bccfbd96.jpeg', 'uid': '6ee87b92564d4259b5a14e9a0dc68920'}, {'name': 'Tree Speed Sculpt', 'image': 'https://media.sketchfab.com/models/23ad7eeb695748778d4c42bc57ec3998/thumbnails/493cfc8576a6401d88d604788aa271db/9e1221ad58044baf863df927030ef22e.jpeg', 'uid': '23ad7eeb695748778d4c42bc57ec3998'}, {'name': 'Palm Tree - Hand Painted', 'image': 'https://media.sketchfab.com/models/fac46087bcc64c33b3d55d2d15167091/thumbnails/0ffbc0c87675464bb96f13d84fab689d/3ff2fe9b569b43e6be24446fc3f8b2eb.jpeg', 'uid': 'fac46087bcc64c33b3d55d2d15167091'}]
# drift_score 12
# load_model_from_vec - Positive Prompts: ["A robot dog carrying a bone in it's mouth", 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'a cartoon drawing of a robotic animal with a', 'image': 'https://media.sketchfab.com/models/22815eb3a5724962bb72db0b0570c097/thumbnails/a8d3ea0258d64d028fd7848eaeda860f/687cdf8c359b417f8e48c513b43f09a3.jpeg', 'uid': '22815eb3a5724962bb72db0b0570c097'}, {'name': 'The Last Dog', 'image': 'https://media.sketchfab.com/models/33dfba8ad7484b92a31c7d1264cb363a/thumbnails/6c2a864aaad24487b961804e1ddfa2a5/aa5af1d1cbc449d78528214aa8bedcac.jpeg', 'uid': '33dfba8ad7484b92a31c7d1264cb363a'}, {'name': 'a painting of a robotic animal with a blue ey', 'image': 'https://media.sketchfab.com/models/15553c668c674bf79eed650aba1c3858/thumbnails/fba97c26c73341a78483c304231ef49b/f9f897c4f2844216b8bbc641d842c557.jpeg', 'uid': '15553c668c674bf79eed650aba1c3858'}, {'name': 'a woman sits on the back of a robotic animal', 'image': 'https://media.sketchfab.com/models/40c4408ed055455684e6bbc36546d099/thumbnails/ea4e50fbf1424ba3944bccb5df35f8f4/21276719d7554ec6b502a009815ed3be.jpeg', 'uid': '40c4408ed055455684e6bbc36546d099'}, {'name': 'a cartoon drawing of a robotic animal with th', 'image': 'https://media.sketchfab.com/models/75f330a79d554702bde970bc4fbc3ab6/thumbnails/163f50bf944e4fedb043e4cb506b4aef/372efe1477a14117a0b3eb81a5824f56.jpeg', 'uid': '75f330a79d554702bde970bc4fbc3ab6'}, {'name': 'Silver Nautilus 47', 'image': 'https://media.sketchfab.com/models/b548e45a6b6f447289afea4adb85b540/thumbnails/27cb1d926c7647d481a4bdfebf782a3f/bb9b0b575c464ca78aacce93d3a51ad8.jpeg', 'uid': 'b548e45a6b6f447289afea4adb85b540'}, {'name': 'a cartoon drawing of a robotic animal standin', 'image': 'https://media.sketchfab.com/models/c31da10d90a9429790f58debd41bb176/thumbnails/461407e23f5a42a5999c7b5fa914db10/2319979dbfe942e7a93a883da0dbbf07.jpeg', 'uid': 'c31da10d90a9429790f58debd41bb176'}, {'name': 'Jake the dog #SGP27', 'image': 'https://media.sketchfab.com/models/9b40a79c9c424cf49af3af26bc78e4c0/thumbnails/47f5a7486978477f80a655e171c80e4b/1024.jpeg', 'uid': '9b40a79c9c424cf49af3af26bc78e4c0'}, {'name': 'Ornithopter - "Flycatcher" | Fantasy plane', 'image': 'https://media.sketchfab.com/models/828eb683e95d412aa5da8e5b13699a67/thumbnails/92946e84a5e447b8b98895aa66814262/6e35442cae514c4589819cab1ac94676.jpeg', 'uid': '828eb683e95d412aa5da8e5b13699a67'}, {'name': 'Bone Loaf Meat', 'image': 'https://media.sketchfab.com/models/6d60d28a8c394d9a9875b5fc49e4b61d/thumbnails/83c3262257954844a2686ba6ae66abe8/ba5da26b3ae44902b804acf9cee6f8b6.jpeg', 'uid': '6d60d28a8c394d9a9875b5fc49e4b61d'}]
# drift_score 12
# load_model_from_vec - Positive Prompts: ['A large troll carrying a club made of bones', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'a man and a woman are flying through the air', 'image': 'https://media.sketchfab.com/models/e5944896955e4423bd6baa3703615f17/thumbnails/6c4d9bdcd66e457b9782e02bd1fc3f53/bdf636cb7bff42408aa26f5b511edd79.jpeg', 'uid': 'e5944896955e4423bd6baa3703615f17'}, {'name': 'a woman sits on the back of a robotic animal', 'image': 'https://media.sketchfab.com/models/40c4408ed055455684e6bbc36546d099/thumbnails/ea4e50fbf1424ba3944bccb5df35f8f4/21276719d7554ec6b502a009815ed3be.jpeg', 'uid': '40c4408ed055455684e6bbc36546d099'}, {'name': 'a painting of a robotic animal with a blue ey', 'image': 'https://media.sketchfab.com/models/15553c668c674bf79eed650aba1c3858/thumbnails/fba97c26c73341a78483c304231ef49b/f9f897c4f2844216b8bbc641d842c557.jpeg', 'uid': '15553c668c674bf79eed650aba1c3858'}, {'name': 'Bone Knife 1', 'image': 'https://media.sketchfab.com/models/b50e0642376a48389c94b128e797f892/thumbnails/670263972cb042d0967820be64bb2c95/8990adf34c0d4c89845543fab33b6f1b.jpeg', 'uid': 'b50e0642376a48389c94b128e797f892'}, {'name': 'a cartoon drawing of a robotic animal with a', 'image': 'https://media.sketchfab.com/models/22815eb3a5724962bb72db0b0570c097/thumbnails/a8d3ea0258d64d028fd7848eaeda860f/687cdf8c359b417f8e48c513b43f09a3.jpeg', 'uid': '22815eb3a5724962bb72db0b0570c097'}, {'name': 'Soul Stealer Bard fan art', 'image': 'https://media.sketchfab.com/models/63d7bfb5e56a44a2a9cdc855137ba16c/thumbnails/c2f671f127604c05a28392a300550d76/1024x576.jpeg', 'uid': '63d7bfb5e56a44a2a9cdc855137ba16c'}, {'name': 'Troll', 'image': 'https://media.sketchfab.com/models/b9c48a350875459fa9246b5a97c1800c/thumbnails/ac799b35b87647cd8e4ff6715892df40/0d1b15936cba4136b3ed32a71f2f2df3.jpeg', 'uid': 'b9c48a350875459fa9246b5a97c1800c'}, {'name': 'Troll', 'image': 'https://media.sketchfab.com/models/ba5424c7f5234925aad7dd415195d8b7/thumbnails/30d1a190653448ba9f97a9881e83db41/1024x576.jpeg', 'uid': 'ba5424c7f5234925aad7dd415195d8b7'}, {'name': 'Troll', 'image': 'https://media.sketchfab.com/models/baf809c224db4a2d95f4e48217800e74/thumbnails/41c5a637d62b444ca0fe09efcfd701ef/6ec33321d2dc467aa8635a870f2ca2b9.jpeg', 'uid': 'baf809c224db4a2d95f4e48217800e74'}, {'name': 'Troll low poly', 'image': 'https://media.sketchfab.com/models/9c507a5b189d48e3a9d60b046dfd85a3/thumbnails/712fceecd1cb40eabc8e04c6a3307e33/8394052960b04823b4fb992a251502b7.jpeg', 'uid': '9c507a5b189d48e3a9d60b046dfd85a3'}]
# drift_score 22
# load_model_from_vec - Positive Prompts: ['An alien carrying a ray gun', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Space Gun', 'image': 'https://media.sketchfab.com/models/4979ba26b80d407f80cafc9fc5997f37/thumbnails/f1922a74a4de490eb61a6a464dc40670/fe2cdaf76e3b4c7eac9503083751de6a.jpeg', 'uid': '4979ba26b80d407f80cafc9fc5997f37'}, {'name': 'Alien Gun', 'image': 'https://media.sketchfab.com/models/b45e973f7ec44de2a015283fe998049b/thumbnails/e65e7f526f2e4d0da21685748e436f8c/6d7d692858dd47e3902a6f8365a81708.jpeg', 'uid': 'b45e973f7ec44de2a015283fe998049b'}, {'name': 'Ice Gun', 'image': 'https://media.sketchfab.com/models/63b73dcf59de461cb5a5a6adc8a557ff/thumbnails/8716417ecfe24dd7ba7205d6b4ab376e/3eaba9ed5347456891471b6fb37fda4b.jpeg', 'uid': '63b73dcf59de461cb5a5a6adc8a557ff'}, {'name': 'Stylized mars gun model', 'image': 'https://media.sketchfab.com/models/7409f71ae70f415780809c2c1cd983b3/thumbnails/5f7e140fffc84863823fd2f854deea52/a4f1137f275b4f92ac8be887485a8bdf.jpeg', 'uid': '7409f71ae70f415780809c2c1cd983b3'}, {'name': 'Atom Ray Gun Waterpistol', 'image': 'https://media.sketchfab.com/models/0b56b78cd702472aa56f44b4ea8924c7/thumbnails/91e9365e7167472d94e0fac86f1b87a7/840786d865b64644afe9feb19b13a206.jpeg', 'uid': '0b56b78cd702472aa56f44b4ea8924c7'}, {'name': '[FREE] Alien Animated Shooter', 'image': 'https://media.sketchfab.com/models/b9d748ccc31344e2966d3f8176aed656/thumbnails/63c56fad30bf462dab9371696dfd7252/d7b22f1543904e44b4efb1a207541aef.jpeg', 'uid': 'b9d748ccc31344e2966d3f8176aed656'}, {'name': 'Ray Gun Bo2 Remastered', 'image': 'https://media.sketchfab.com/models/253fdae1c12f4e81937aba007702ae60/thumbnails/a7069fb8c01a45c99ab69f64522b82bc/46573387a1d24279af13bc2cee0c4ef2.jpeg', 'uid': '253fdae1c12f4e81937aba007702ae60'}, {'name': 'Basic Ray Gun [Wander A Nebula]', 'image': 'https://media.sketchfab.com/models/a23487f257d24fc6b717e822db63136a/thumbnails/2bf0b46915c34105ba11a9cb706d4da3/0b1d8a523ee9415a8b565c851b2fa1c8.jpeg', 'uid': 'a23487f257d24fc6b717e822db63136a'}, {'name': 'Cartoon alien gun', 'image': 'https://media.sketchfab.com/models/707ddadaaf194574aad0773e03e74d97/thumbnails/a56eb374b15d4bb99ddf81beeb94d2ea/8da4d04d318c46048ac848321949ce4e.jpeg', 'uid': '707ddadaaf194574aad0773e03e74d97'}, {'name': '"Anime Style A fierce-looking blue alien warrior', 'image': 'https://media.sketchfab.com/models/6cab25b8ac96485dbe591f04607b9381/thumbnails/63bf8674aa6c4a4d8e0d83bcf9f294ed/c63c666c42624cd2858fd584efe53c56.jpeg', 'uid': '6cab25b8ac96485dbe591f04607b9381'}]
# drift_score 22
# load_model_from_vec - Positive Prompts: ['Large Ice sculpture of a figure skater', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'jenkins_Snowscreem', 'image': 'https://media.sketchfab.com/models/98cd0228eb4c44a0bf32351bb3abaef4/thumbnails/284e2ca919b543dd9e3a8265e821577d/8a819d88b24242a4871444eb5004eaef.jpeg', 'uid': '98cd0228eb4c44a0bf32351bb3abaef4'}, {'name': 'a colorful statue of a woman with bubbles aro', 'image': 'https://media.sketchfab.com/models/9c69ffc8a44a431f9cfdf0eb78d82b8f/thumbnails/05174c99310147f2a6739a9cc8fd8835/d8276b5f7e0b4d89b9c7ea3774a54b80.jpeg', 'uid': '9c69ffc8a44a431f9cfdf0eb78d82b8f'}, {'name': 'Abstract figure', 'image': 'https://media.sketchfab.com/models/f61021728b83487497e948670fcdc424/thumbnails/323aff2b68d74130ae2dc24f2a1aec2b/983554d4d0e941599c55f49fec46ff77.jpeg', 'uid': 'f61021728b83487497e948670fcdc424'}, {'name': 'Iced Cream', 'image': 'https://media.sketchfab.com/models/0a15495102d545f4bb98369e4dedc2f4/thumbnails/dac87aa0f2c342fa8049185f84825310/281d43edfb9a40e2b941fa2fb4b33c0e.jpeg', 'uid': '0a15495102d545f4bb98369e4dedc2f4'}, {'name': 'Abstract Sculpture', 'image': 'https://media.sketchfab.com/models/b92408f5674a4df68e1eb8686d6d7d2d/thumbnails/9631bf73a2d841a5b8b4117cd5bc6c4f/31ce3422c7c940d68fdef6e39464ca8d.jpeg', 'uid': 'b92408f5674a4df68e1eb8686d6d7d2d'}, {'name': 'Avali Firelance', 'image': 'https://media.sketchfab.com/models/c6f7e65c88ab4aacb279ef732e6fa856/thumbnails/83ffc479d2f14bc885e59d36019bb302/be921c2d24034f1f998ea70b6289a5de.jpeg', 'uid': 'c6f7e65c88ab4aacb279ef732e6fa856'}, {'name': 'Stylized Toffee Apple Light', 'image': 'https://media.sketchfab.com/models/d0a2247fbe2840c3931d59e831144c34/thumbnails/0b48ef0654064e1785103c167b685801/4e8f720fec524b10bc02c31148de902e.jpeg', 'uid': 'd0a2247fbe2840c3931d59e831144c34'}, {'name': 'a colorful sculpture with bubbles coming out', 'image': 'https://media.sketchfab.com/models/ca35953a02f2448d809527162ed9e8f3/thumbnails/e11744f033d14618aa53cefd93eb1d46/1a331c9533da45358e33a62ed22eb02b.jpeg', 'uid': 'ca35953a02f2448d809527162ed9e8f3'}, {'name': "Armored Spider-Man (Tony Hawk's Pro Skater 2)", 'image': 'https://media.sketchfab.com/models/d5c88f05cdea4c858cbc4dce40ec9939/thumbnails/29f6981e712b4fa0a90f98143f811e2b/46f41158e7ac46b0a7eb33edd0070d67.jpeg', 'uid': 'd5c88f05cdea4c858cbc4dce40ec9939'}, {'name': 'The image is a striking digital art piece, domin', 'image': 'https://media.sketchfab.com/models/c9a717803a044535808f7c77e1cb4810/thumbnails/fab1bac0307a4c65a78586684bfc96d5/1595f35ad88145ecb244f9349c652e87.jpeg', 'uid': 'c9a717803a044535808f7c77e1cb4810'}]
# drift_score 23
# load_model_from_vec - Positive Prompts: ['Christmas tree with a shining star at the top', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Christmas Star', 'image': 'https://media.sketchfab.com/models/de23837809ab4afa92e73bc3244100d4/thumbnails/62a078ff1c9a4606a3234d813bfb5750/602ca0293d684bb5bf2d85e2f5496202.jpeg', 'uid': 'de23837809ab4afa92e73bc3244100d4'}, {'name': 'Small Sea Plant', 'image': 'https://media.sketchfab.com/models/0a4e780761eb440da07c8532b8ea7346/thumbnails/40ab28b7fd9f41818009ab2e19bc056e/187ddfc34b9140298bdb0f81b12ae219.jpeg', 'uid': '0a4e780761eb440da07c8532b8ea7346'}, {'name': 'Shooting Star', 'image': 'https://media.sketchfab.com/models/896c5694c1d44176ba40abae09be3b98/thumbnails/cb59cbf4d4fe4f0b95658645ff89e1b5/035d5132ebc144838ca4d0a6e705bb93.jpeg', 'uid': '896c5694c1d44176ba40abae09be3b98'}, {'name': 'Pine_Tree', 'image': 'https://media.sketchfab.com/models/fbd656918d5e4126b82c7b41432aff5f/thumbnails/f939c45bddcb4fe78630ec3b65d74b0d/b46c6c7822164bea8231c42290e70f0d.jpeg', 'uid': 'fbd656918d5e4126b82c7b41432aff5f'}, {'name': 'christmas-star', 'image': 'https://media.sketchfab.com/models/0c4754201b074ba980032e26bc9c7598/thumbnails/65dc42a9384c4133932446dcac5dc6ad/311b3b52525e4042bd7106afad9c7d7f.jpeg', 'uid': '0c4754201b074ba980032e26bc9c7598'}, {'name': 'Christmas tree', 'image': 'https://media.sketchfab.com/models/2683bbd6f802480cb36c901d357ff119/thumbnails/92b28f8188d9418e80855698f4f67aeb/c07b9ef8419849b7a713d08492679db1.jpeg', 'uid': '2683bbd6f802480cb36c901d357ff119'}, {'name': 'Shining star low poly', 'image': 'https://media.sketchfab.com/models/72e462e4946b4bbb9a6c18e876f04784/thumbnails/aa3cbf8ce9084cc38a4fa6d518b8292f/d72cd07a7c2e401a97a8b076ec25f6ad.jpeg', 'uid': '72e462e4946b4bbb9a6c18e876f04784'}, {'name': 'Christmas Tree Bauble', 'image': 'https://media.sketchfab.com/models/a21c89d379594eafa27ed9666d3be060/thumbnails/78c8bcf7fd9b44e2a4ab1261e983ed99/945a6857e11449d89df7d96f6fd27857.jpeg', 'uid': 'a21c89d379594eafa27ed9666d3be060'}, {'name': 'Christmas Glitter Ball', 'image': 'https://media.sketchfab.com/models/a383eac7ff8149acb335cce771740740/thumbnails/0795166fc63748a4a310e9b845d24825/6f00e492f45b44b089cd862168b09a91.jpeg', 'uid': 'a383eac7ff8149acb335cce771740740'}, {'name': 'Wooden Christmas Tree Decoration with Lights', 'image': 'https://media.sketchfab.com/models/c59b8862339f45a29162049af7856c3d/thumbnails/13ea81289b76440c9c15c493938e786e/3573ef1237c244a0b07d033253cb4415.jpeg', 'uid': 'c59b8862339f45a29162049af7856c3d'}]
# drift_score 28
# load_model_from_vec - Positive Prompts: ['A dumptruck with yellow paint', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Dump Truck (Split/Second: Velocity)', 'image': 'https://media.sketchfab.com/models/d019630deb734ea9b7e00d8f18a8bd16/thumbnails/00fdad63c2624bf087a4bcf7c12d5be6/7e4152d8fa4547e69b2edf7103913cd2.jpeg', 'uid': 'd019630deb734ea9b7e00d8f18a8bd16'}, {'name': 'Yellow Minecraft Pickup', 'image': 'https://media.sketchfab.com/models/c4862866a1d64513b95ff04e2ef10fe7/thumbnails/703414df82844bd28407341496388c08/52a09b25cdbc4239bf99296cc0cb4d3b.jpeg', 'uid': 'c4862866a1d64513b95ff04e2ef10fe7'}, {'name': 'Military Jeep / Jeep (Pixel Style)', 'image': 'https://media.sketchfab.com/models/3d701670a73644a9b897d9595ba5a068/thumbnails/3bc919c644524cb786e8f6b2ff59cd19/344aff9faef049a9b20c86e6f62aa900.jpeg', 'uid': '3d701670a73644a9b897d9595ba5a068'}, {'name': 'M-920 Cain - Acid Gun', 'image': 'https://media.sketchfab.com/models/5299e6b308a147a4b683b9b1654c1e5d/thumbnails/4f5436c410214820a2e057dc872e2a86/b386dc638d634bda8fd3db597c5c0af6.jpeg', 'uid': '5299e6b308a147a4b683b9b1654c1e5d'}, {'name': 'A100 Surround Ripley Aliens Movie Prop', 'image': 'https://media.sketchfab.com/models/1478cdf918794787bc83516d7bffe34d/thumbnails/f8b7e7c2c0e34f9688aea323186623b7/b4fdcfbc465c48fb85a324b3a5d57948.jpeg', 'uid': '1478cdf918794787bc83516d7bffe34d'}, {'name': 'Gun', 'image': 'https://media.sketchfab.com/models/8530f957dae0409bbbaa4ffea0bd7efe/thumbnails/6c6834f22ab7476f8b6ea1e6b5fc98fd/13ee881c04604a2f8add338b4c8280bb.jpeg', 'uid': '8530f957dae0409bbbaa4ffea0bd7efe'}, {'name': 'a painting of a robotic animal with a blue ey', 'image': 'https://media.sketchfab.com/models/15553c668c674bf79eed650aba1c3858/thumbnails/fba97c26c73341a78483c304231ef49b/f9f897c4f2844216b8bbc641d842c557.jpeg', 'uid': '15553c668c674bf79eed650aba1c3858'}, {'name': 'Gun10,  Modified M-920 Cain.', 'image': 'https://media.sketchfab.com/models/4ef139948c59496f84f631dddac6a12c/thumbnails/35353f6df39c4576937b67e8b30b492a/58afde22c04542dda688046d5f80796c.jpeg', 'uid': '4ef139948c59496f84f631dddac6a12c'}, {'name': 'chicken gun laser magnum', 'image': 'https://media.sketchfab.com/models/4360ab08e8a84a89b843af5e9ed6f7e9/thumbnails/1a200d25f1c74e159c8670b3cf318f23/2cc037c9d92a4a9a9772d1ea5ce50972.jpeg', 'uid': '4360ab08e8a84a89b843af5e9ed6f7e9'}, {'name': 'Ground floor with acid puddles', 'image': 'https://media.sketchfab.com/models/5e2953deef6e458d9e0d1f38a98da107/thumbnails/89d0ee5190a84f27b60548ee7462e99f/01dfcb6797df42c39aca0531b03f8cc6.jpeg', 'uid': '5e2953deef6e458d9e0d1f38a98da107'}]
# drift_score 38
# load_model_from_vec - Positive Prompts: ['small cottage surrounded by grass', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Hand Painted House', 'image': 'https://media.sketchfab.com/models/816a9104b90d4a449f5162f7c144a54a/thumbnails/fb81743e771f4cdebdda5f0e0370536a/d02f16cd3c7a448185165df8c3f6fa26.jpeg', 'uid': '816a9104b90d4a449f5162f7c144a54a'}, {'name': 'lonely cottage', 'image': 'https://media.sketchfab.com/models/46491f9d827344e38c5be471d8e59d01/thumbnails/4152d3c5471748959694afe23c1fec16/140d0894fac44245843605e464f1062a.jpeg', 'uid': '46491f9d827344e38c5be471d8e59d01'}, {'name': 'Cottage House - 3DDecember Day4', 'image': 'https://media.sketchfab.com/models/46382f2e67284903b2f3f04662377a04/thumbnails/fc336c76e6524a88bb822415212872a6/fa1570bdc5d148dfab658a4b91371019.jpeg', 'uid': '46382f2e67284903b2f3f04662377a04'}, {'name': 'Cartoon House', 'image': 'https://media.sketchfab.com/models/7eba385300b54728b972b89938b792e3/thumbnails/b2b977d733fd4c50aaf359f52537bcee/10e5dd04fa914a94a7fa279ec1ed0007.jpeg', 'uid': '7eba385300b54728b972b89938b792e3'}, {'name': 'Small Barracks', 'image': 'https://media.sketchfab.com/models/6bf1d1cb834d433bb3cd169695d87bc2/thumbnails/b44df80b78bc48d096ec7933c50d78b7/e7cfa83de34e47748207970314d8c06c.jpeg', 'uid': '6bf1d1cb834d433bb3cd169695d87bc2'}, {'name': 'Wood Cottage - Lowpoly', 'image': 'https://media.sketchfab.com/models/1f0e4563c9b6421f8bb73d3f059d5ef4/thumbnails/fbab98afbe494e5783af5f0a8022f6d9/7338d3346d3c4c0d92d28abb9bd37b31.jpeg', 'uid': '1f0e4563c9b6421f8bb73d3f059d5ef4'}, {'name': 'cozy cottage', 'image': 'https://media.sketchfab.com/models/bf3612cf8f8c4b279d45d3006c368e44/thumbnails/6910bcc05cd345f0aa84b726b512738b/653432d23bbb44cc823cf7fdd11c5875.jpeg', 'uid': 'bf3612cf8f8c4b279d45d3006c368e44'}, {'name': 'cottage', 'image': 'https://media.sketchfab.com/models/39400d4df322499f959d04a5c1151d98/thumbnails/6964b6060c974245890fbd1dd6658fa3/50fff333e30f44b09f208f8ad81ca712.jpeg', 'uid': '39400d4df322499f959d04a5c1151d98'}, {'name': 'Low poly Cottage', 'image': 'https://media.sketchfab.com/models/8bae51b270a941f7b2d1c8f836737d9f/thumbnails/177db3507d5448cb9721ad926bc85fbd/12f5d36a2614401aa4d9115551515f85.jpeg', 'uid': '8bae51b270a941f7b2d1c8f836737d9f'}, {'name': 'GameReady Cottage FREE', 'image': 'https://media.sketchfab.com/models/9203e8f4b67b4d9e8b32c10b2d5e6a57/thumbnails/30f9d6b21d4240be98ebf1d5b60481ae/0fe12be03495499c9f96c5795fba9cfa.jpeg', 'uid': '9203e8f4b67b4d9e8b32c10b2d5e6a57'}]
# drift_score 38
# load_model_from_vec - Positive Prompts: ['Silver car', 'cohesive attractive design', 'high poly high quality', 'attractive and pretty colors', 'cohesive single object', 'object with a solid base']
# load_model_from_vec - Negative Prompts: ['object in a room', 'a complete room', 'ugly or low quality', 'low poly', 'abstract and disconnected', 'black and white', 'greyscale']
# [{'name': 'Mercedes-Benz Silver Lightning', 'image': 'https://media.sketchfab.com/models/cfba13ac9ad6440db68d6a65c22a01ed/thumbnails/47f98454fcd94794b680de12082b4724/d858ecb090c44f14bb48eb659f9dda52.jpeg', 'uid': 'cfba13ac9ad6440db68d6a65c22a01ed'}, {'name': '2001 Mercedes-Benz A160 Hatchback', 'image': 'https://media.sketchfab.com/models/2cff998e65d44480af9d021a003ef000/thumbnails/c379468970af45ae87d7e12202018f52/ce8c462711e24101afec9650db66e723.jpeg', 'uid': '2cff998e65d44480af9d021a003ef000'}, {'name': 'Sport Car', 'image': 'https://media.sketchfab.com/models/5bf9eb1870594f91a937e8cc2eb922f9/thumbnails/1ddfe8bef1ab4618b31ed864c613bf8a/219a3e6332ca43d6b85dd6a45e02a572.jpeg', 'uid': '5bf9eb1870594f91a937e8cc2eb922f9'}, {'name': 'Kazē Strike fighter (The Koryu Unity)', 'image': 'https://media.sketchfab.com/models/50d5f90d49b44f7589d19b620a625c78/thumbnails/03d46510208f4a5c959d06193a965c33/19d19a379a044ca48a7dc92f8f8886e6.jpeg', 'uid': '50d5f90d49b44f7589d19b620a625c78'}, {'name': 'Jeep Renegade 2016', 'image': 'https://media.sketchfab.com/models/192f7e81dce84c6780434f692a0f96c5/thumbnails/d33ed87b3f70409f937314ae905d044d/41fa0e482b694975b21226d46f1d40e0.jpeg', 'uid': '192f7e81dce84c6780434f692a0f96c5'}, {'name': 'Generic 80s european car', 'image': 'https://media.sketchfab.com/models/af108d4773df4722a62420f65dd5b8fe/thumbnails/28dccb69262340a8a1483c74079606c8/1024x576.jpeg', 'uid': 'af108d4773df4722a62420f65dd5b8fe'}, {'name': 'Silver Nautilus 47', 'image': 'https://media.sketchfab.com/models/b548e45a6b6f447289afea4adb85b540/thumbnails/27cb1d926c7647d481a4bdfebf782a3f/bb9b0b575c464ca78aacce93d3a51ad8.jpeg', 'uid': 'b548e45a6b6f447289afea4adb85b540'}, {'name': 'Silver Bullet', 'image': 'https://media.sketchfab.com/models/b3ea30853b664baf85e01cd57e8fb4b5/thumbnails/bd10615ecfdf4cefbfee82aa80ee7121/e40f3c8d44434f20882804bba40ed8a9.jpeg', 'uid': 'b3ea30853b664baf85e01cd57e8fb4b5'}, {'name': 'Low Poly Car', 'image': 'https://media.sketchfab.com/models/93971323324243468f24d7da9d18f617/thumbnails/14a78f43c4844f02b3062820cb5b4040/1024x576.jpeg', 'uid': '93971323324243468f24d7da9d18f617'}, {'name': 'Little Robot Ball', 'image': 'https://media.sketchfab.com/models/bd1792fd94fc4e82a043b8724bad8f75/thumbnails/12c39439bef248bca75fc5daa0617919/fb3ce1cd802b44a38cd3e5341986decc.jpeg', 'uid': 'bd1792fd94fc4e82a043b8724bad8f75'}]
# drift_score 40
# drift_score 40

# %%
print("drift_score", drift_score)
max_score = len(ideal_dataset) * max_score_per_item
print("accuracy", (max_score - drift_score) / max_score)
# Out:
# drift_score 40
# accuracy 0.7142857142857143

# %%
print("saved_model_data_filename", saved_model_data_filename)
print("existing_image_features_filename", existing_image_features_filename)
print("existing_text_features_filename", existing_text_features_filename)

if num_model_loads > 0 and stack_existing_image_features and not freeze_model_database_models:
    with open(saved_model_data_filename, "w") as f:
        saved_model_data = { "existing_searches_done": existing_searches_done, "list_of_all_models": list_of_all_models, "index_to_model_uid": index_to_model_uid }
        json.dump(saved_model_data, f)
    torch.save(existing_image_features.cpu().detach(), existing_image_features_filename)
    torch.save(existing_text_features.cpu().detach(), existing_text_features_filename)
    print("num_model_loads", num_model_loads, "list_of_all_models", len(list_of_all_models))
else:
    print("none saved")
    if freeze_model_database_models:
        print("model database frozen")
# Out:
# saved_model_data_filename ./saved_model_data_ViT-H_14-378.json
# existing_image_features_filename ./existing_image_features_ViT-H_14-378.pt
# existing_text_features_filename ./existing_text_features_ViT-H_14-378.pt
# none saved
# model database frozen
